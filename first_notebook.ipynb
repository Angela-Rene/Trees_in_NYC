# %% [markdown]
# This Notebook is for cleaning the data sets, EDA, and creating custom functions.
#
# Importing needed libraries:

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# Importing and cleaning first data set(Tree census):

# %%
tree_df = pd.read_csv("new_york_tree_census_2015.csv")
tree_df.head()
# Out:
#    tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status health  \
# 0   606945    305778  2016-06-28        10           0   OnCurb  Alive   Good
# 1   160321    341273  2015-08-19         9           0   OnCurb  Alive   Good
# 2   541347    325281  2015-12-30         7           0   OnCurb  Alive   Good
# 3   613930    203822  2016-07-05        10           0   OnCurb  Alive   Good
# 4    18353    338911  2015-06-13         4           0   OnCurb  Alive   Good
#
#                             spc_latin              spc_common  ... st_assem  \
# 0              Fraxinus pennsylvanica               green ash  ...       25
# 1  Gleditsia triacanthos var. inermis             honeylocust  ...       34
# 2                    Pyrus calleryana            Callery pear  ...       32
# 3                    Pyrus calleryana            Callery pear  ...       46
# 4                   Prunus virginiana  'Schubert' chokecherry  ...       31
#
#   st_senate   nta                  nta_name  boro_ct     state   latitude  \
# 0        14  QN37         Kew Gardens Hills  4125700  New York  40.724339
# 1        13  QN28           Jackson Heights  4030902  New York  40.756626
# 2        10  QN76              Baisley Park  4028800  New York  40.679777
# 3        22  BK31                 Bay Ridge  3005000  New York  40.622743
# 4        10  QN12  Hammels-Arverne-Edgemere  4095400  New York  40.596514
#
#    longitude          x_sp         y_sp
# 0 -73.805180  1.038250e+06  203232.9417
# 1 -73.894167  1.013571e+06  214953.6472
# 2 -73.788463  1.042923e+06  187008.2671
# 3 -74.037543  9.738279e+05  166160.5847
# 4 -73.797622  1.040452e+06  156667.5017
#
# [5 rows x 41 columns]

# %%
#keeping only living trees:
remove_values = ["Dead", "Stump"]
alive_df = tree_df[~tree_df["status"].isin(remove_values)]
alive_df.describe()
# Out:
#              tree_id       block_id       tree_dbh  stump_diam        zipcode  \
# count  652173.000000  652173.000000  652173.000000    652173.0  652173.000000
# mean   365689.637480  313611.213077      11.709485         0.0   10914.407958
# std    208194.926983  114775.077889       8.634239         0.0     656.868397
# min         3.000000  100002.000000       0.000000         0.0      83.000000
# 25%    186886.000000  221491.000000       5.000000         0.0   10314.000000
# 50%    367204.000000  319886.000000      10.000000         0.0   11214.000000
# 75%    546632.000000  404665.000000      16.000000         0.0   11365.000000
# max    722694.000000  999999.000000     425.000000         0.0   11697.000000
#
#               cb_num       borocode       cncldist       st_assem  \
# count  652173.000000  652173.000000  652173.000000  652173.000000
# mean      343.738388       3.360979      29.992976      50.818103
# std       115.808325       1.167572      14.343667      18.928937
# min       101.000000       1.000000       1.000000      23.000000
# 25%       303.000000       3.000000      19.000000      33.000000
# 50%       402.000000       4.000000      30.000000      52.000000
# 75%       412.000000       4.000000      43.000000      64.000000
# max       503.000000       5.000000      51.000000      87.000000
#
#            st_senate       boro_ct       latitude      longitude  \
# count  652173.000000  6.521730e+05  652173.000000  652173.000000
# mean       20.620725  3.407340e+06      40.700991     -73.924587
# std         7.378427  1.176612e+06       0.090268       0.123844
# min        10.000000  1.000201e+06      40.498466     -74.254965
# 25%        14.000000  3.012000e+06      40.631725     -73.980973
# 50%        21.000000  4.008100e+06      40.700287     -73.913449
# 75%        25.000000  4.103300e+06      40.761999     -73.835219
# max        36.000000  5.032300e+06      40.912918     -73.700488
#
#                x_sp           y_sp
# count  6.521730e+05  652173.000000
# mean   1.005133e+06  194699.696220
# std    3.435720e+04   32886.140551
# min    9.133493e+05  120973.792200
# 25%    9.895259e+05  169441.751400
# 50%    1.008235e+06  194444.837500
# 75%    1.029902e+06  216940.389000
# max    1.067248e+06  271894.092100

# %%
#dropping unneeded columns:
filtered_df = alive_df.drop(['created_at', 'stump_diam', 'status', 'user_type', 'sidewalk', 'guards', 'steward', 'st_assem', 
                             'st_senate', 'root_stone', 'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
                             'brch_light', 'brch_shoe', 'brch_other'], axis=1)
filtered_df.head()
# Out:
#    tree_id  block_id  tree_dbh curb_loc health  \
# 0   606945    305778        10   OnCurb   Good
# 1   160321    341273         9   OnCurb   Good
# 2   541347    325281         7   OnCurb   Good
# 3   613930    203822        10   OnCurb   Good
# 4    18353    338911         4   OnCurb   Good
#
#                             spc_latin              spc_common      problems  \
# 0              Fraxinus pennsylvanica               green ash        Stones
# 1  Gleditsia triacanthos var. inermis             honeylocust  BranchLights
# 2                    Pyrus calleryana            Callery pear  BranchLights
# 3                    Pyrus calleryana            Callery pear           NaN
# 4                   Prunus virginiana  'Schubert' chokecherry  BranchLights
#
#                address  zipcode  ...  boroname  cncldist   nta  \
# 0    76-046 164 STREET    11366  ...    Queens        24  QN37
# 1     72-020 32 AVENUE    11370  ...    Queens        25  QN28
# 2   153-026 119 AVENUE    11434  ...    Queens        28  QN76
# 3         89 89 STREET    11209  ...  Brooklyn        43  BK31
# 4  559 BEACH 68 STREET    11692  ...    Queens        31  QN12
#
#                    nta_name  boro_ct     state   latitude  longitude  \
# 0         Kew Gardens Hills  4125700  New York  40.724339 -73.805180
# 1           Jackson Heights  4030902  New York  40.756626 -73.894167
# 2              Baisley Park  4028800  New York  40.679777 -73.788463
# 3                 Bay Ridge  3005000  New York  40.622743 -74.037543
# 4  Hammels-Arverne-Edgemere  4095400  New York  40.596514 -73.797622
#
#            x_sp         y_sp
# 0  1.038250e+06  203232.9417
# 1  1.013571e+06  214953.6472
# 2  1.042923e+06  187008.2671
# 3  9.738279e+05  166160.5847
# 4  1.040452e+06  156667.5017
#
# [5 rows x 23 columns]

# %% [markdown]
# Addressing null or unclear values:

# %%
filtered_df.isnull().sum()
# Out:
# tree_id            0
# block_id           0
# tree_dbh           0
# curb_loc           0
# health             1
# spc_latin          5
# spc_common         5
# problems      426329
# address            0
# zipcode            0
# zip_city           0
# cb_num             0
# borocode           0
# boroname           0
# cncldist           0
# nta                0
# nta_name           0
# boro_ct            0
# state              0
# latitude           0
# longitude          0
# x_sp               0
# y_sp               0
# dtype: int64

# %%
filtered_df.dropna(subset=["health", "spc_latin", "spc_common"], inplace=True)

# %%
filtered_df["problems"] = filtered_df["problems"].fillna("no problems")
filtered_df.head()
# Out:
#    tree_id  block_id  tree_dbh curb_loc health  \
# 0   606945    305778        10   OnCurb   Good
# 1   160321    341273         9   OnCurb   Good
# 2   541347    325281         7   OnCurb   Good
# 3   613930    203822        10   OnCurb   Good
# 4    18353    338911         4   OnCurb   Good
#
#                             spc_latin              spc_common      problems  \
# 0              Fraxinus pennsylvanica               green ash        Stones
# 1  Gleditsia triacanthos var. inermis             honeylocust  BranchLights
# 2                    Pyrus calleryana            Callery pear  BranchLights
# 3                    Pyrus calleryana            Callery pear   no problems
# 4                   Prunus virginiana  'Schubert' chokecherry  BranchLights
#
#                address  zipcode  ...  boroname  cncldist   nta  \
# 0    76-046 164 STREET    11366  ...    Queens        24  QN37
# 1     72-020 32 AVENUE    11370  ...    Queens        25  QN28
# 2   153-026 119 AVENUE    11434  ...    Queens        28  QN76
# 3         89 89 STREET    11209  ...  Brooklyn        43  BK31
# 4  559 BEACH 68 STREET    11692  ...    Queens        31  QN12
#
#                    nta_name  boro_ct     state   latitude  longitude  \
# 0         Kew Gardens Hills  4125700  New York  40.724339 -73.805180
# 1           Jackson Heights  4030902  New York  40.756626 -73.894167
# 2              Baisley Park  4028800  New York  40.679777 -73.788463
# 3                 Bay Ridge  3005000  New York  40.622743 -74.037543
# 4  Hammels-Arverne-Edgemere  4095400  New York  40.596514 -73.797622
#
#            x_sp         y_sp
# 0  1.038250e+06  203232.9417
# 1  1.013571e+06  214953.6472
# 2  1.042923e+06  187008.2671
# 3  9.738279e+05  166160.5847
# 4  1.040452e+06  156667.5017
#
# [5 rows x 23 columns]

# %%
filtered_df["zipcode"].unique()
# Out:
# array([11366, 11370, 11434, 11209, 11692, 10031, 11207, 11219, 11421,
#        10474, 11419, 10308, 10001, 10312, 11234, 10305, 11201, 11233,
#        11411, 11220, 10009, 11372, 11432, 10314, 10461, 10309, 11367,
#        11205, 10025, 11374, 11105, 11217, 10458, 11001, 10459, 11364,
#        11379, 11691, 11004, 11358, 11238, 11213, 10470, 11356, 11103,
#        11361, 10007, 11385, 11355, 11230, 10469, 10468, 10032, 11426,
#        10304, 10463, 11206, 10462, 11216, 11208, 10465, 11375, 11429,
#        11365, 11435, 11218, 10034, 11414, 11412, 11377, 11223, 11427,
#        11204, 11357, 10022, 11215, 11428, 10036, 10456, 10024, 11221,
#        10467, 10026, 11420, 11423, 10038, 11231, 11369, 11413, 10453,
#        11210, 11436, 10307, 10475, 11229, 11363, 11040, 10003, 10457,
#        11212, 11373, 11360, 11418, 11226, 10301, 10473, 10472, 11225,
#        10302, 11422, 11354, 11236, 11106, 10013, 11214, 10452, 11378,
#        10466, 10012,    83, 10310, 11694, 10002, 11224, 10464, 10035,
#        11415, 10306, 11222, 10303, 11368, 10014, 10451, 11433, 11239,
#        10021, 10018, 11237, 11235, 11249, 11211, 10017, 10029, 10128,
#        11102, 10011, 11104, 11693, 10019, 10006, 11228, 10040, 10455,
#        11362, 10028, 10471, 10033, 10454, 11101, 10023, 10065, 11203,
#        10075, 10460, 10016, 11371, 10037, 11416, 10027, 10004, 11232,
#        10039, 10010, 10030, 11417, 10020, 11109, 10281, 11251, 10069,
#        10280, 10005, 11430, 10282, 11005, 11697, 10111, 11096, 10115,
#        11451, 10048])

# %%
filtered_df = filtered_df[filtered_df["zipcode"] != 83]
filtered_df["zipcode"].unique()
# Out:
# array([11366, 11370, 11434, 11209, 11692, 10031, 11207, 11219, 11421,
#        10474, 11419, 10308, 10001, 10312, 11234, 10305, 11201, 11233,
#        11411, 11220, 10009, 11372, 11432, 10314, 10461, 10309, 11367,
#        11205, 10025, 11374, 11105, 11217, 10458, 11001, 10459, 11364,
#        11379, 11691, 11004, 11358, 11238, 11213, 10470, 11356, 11103,
#        11361, 10007, 11385, 11355, 11230, 10469, 10468, 10032, 11426,
#        10304, 10463, 11206, 10462, 11216, 11208, 10465, 11375, 11429,
#        11365, 11435, 11218, 10034, 11414, 11412, 11377, 11223, 11427,
#        11204, 11357, 10022, 11215, 11428, 10036, 10456, 10024, 11221,
#        10467, 10026, 11420, 11423, 10038, 11231, 11369, 11413, 10453,
#        11210, 11436, 10307, 10475, 11229, 11363, 11040, 10003, 10457,
#        11212, 11373, 11360, 11418, 11226, 10301, 10473, 10472, 11225,
#        10302, 11422, 11354, 11236, 11106, 10013, 11214, 10452, 11378,
#        10466, 10012, 10310, 11694, 10002, 11224, 10464, 10035, 11415,
#        10306, 11222, 10303, 11368, 10014, 10451, 11433, 11239, 10021,
#        10018, 11237, 11235, 11249, 11211, 10017, 10029, 10128, 11102,
#        10011, 11104, 11693, 10019, 10006, 11228, 10040, 10455, 11362,
#        10028, 10471, 10033, 10454, 11101, 10023, 10065, 11203, 10075,
#        10460, 10016, 11371, 10037, 11416, 10027, 10004, 11232, 10039,
#        10010, 10030, 11417, 10020, 11109, 10281, 11251, 10069, 10280,
#        10005, 11430, 10282, 11005, 11697, 10111, 11096, 10115, 11451,
#        10048])

# %%
filtered_df.isnull().sum()
# Out:
# tree_id       0
# block_id      0
# tree_dbh      0
# curb_loc      0
# health        0
# spc_latin     0
# spc_common    0
# problems      0
# address       0
# zipcode       0
# zip_city      0
# cb_num        0
# borocode      0
# boroname      0
# cncldist      0
# nta           0
# nta_name      0
# boro_ct       0
# state         0
# latitude      0
# longitude     0
# x_sp          0
# y_sp          0
# dtype: int64

# %%
#dropping more unneeded columns:
tree_df = filtered_df.drop(["block_id", "state", "cncldist", "nta", "boro_ct", "spc_latin", "address", "zip_city"], axis=1)
tree_df = tree_df.reset_index()
tree_df.head()
# Out:
#    index  tree_id  tree_dbh curb_loc health              spc_common  \
# 0      0   606945        10   OnCurb   Good               green ash
# 1      1   160321         9   OnCurb   Good             honeylocust
# 2      2   541347         7   OnCurb   Good            Callery pear
# 3      3   613930        10   OnCurb   Good            Callery pear
# 4      4    18353         4   OnCurb   Good  'Schubert' chokecherry
#
#        problems  zipcode  cb_num  borocode  boroname  \
# 0        Stones    11366     408         4    Queens
# 1  BranchLights    11370     403         4    Queens
# 2  BranchLights    11434     412         4    Queens
# 3   no problems    11209     310         3  Brooklyn
# 4  BranchLights    11692     414         4    Queens
#
#                    nta_name   latitude  longitude          x_sp         y_sp
# 0         Kew Gardens Hills  40.724339 -73.805180  1.038250e+06  203232.9417
# 1           Jackson Heights  40.756626 -73.894167  1.013571e+06  214953.6472
# 2              Baisley Park  40.679777 -73.788463  1.042923e+06  187008.2671
# 3                 Bay Ridge  40.622743 -74.037543  9.738279e+05  166160.5847
# 4  Hammels-Arverne-Edgemere  40.596514 -73.797622  1.040452e+06  156667.5017

# %% [markdown]
# Creating a function to make a quantitative tree health score:

# %%
tree_df["health"].unique()
# Out:
# array(['Good', 'Fair', 'Poor'], dtype=object)

# %%
def tree_health_score(health: str) -> int:
    """
    Args:
    health (str): health column lists status as "Good", "Fair", and "Poor"
    
    Returns:
    int: a score where Good =3, Fair = 2, and Poor = 1
    returns 0 if input is not recognized or missing
    """
    scores = {"Good": 3, "Fair": 2, "Poor": 1}
    return scores.get(health, 0)

#creating new column for health score:
tree_df["health_score"] = tree_df["health"].apply(tree_health_score)
tree_df.head()
# Out:
#    index  tree_id  tree_dbh curb_loc health              spc_common  \
# 0      0   606945        10   OnCurb   Good               green ash
# 1      1   160321         9   OnCurb   Good             honeylocust
# 2      2   541347         7   OnCurb   Good            Callery pear
# 3      3   613930        10   OnCurb   Good            Callery pear
# 4      4    18353         4   OnCurb   Good  'Schubert' chokecherry
#
#        problems  zipcode  cb_num  borocode  boroname  \
# 0        Stones    11366     408         4    Queens
# 1  BranchLights    11370     403         4    Queens
# 2  BranchLights    11434     412         4    Queens
# 3   no problems    11209     310         3  Brooklyn
# 4  BranchLights    11692     414         4    Queens
#
#                    nta_name   latitude  longitude          x_sp         y_sp  \
# 0         Kew Gardens Hills  40.724339 -73.805180  1.038250e+06  203232.9417
# 1           Jackson Heights  40.756626 -73.894167  1.013571e+06  214953.6472
# 2              Baisley Park  40.679777 -73.788463  1.042923e+06  187008.2671
# 3                 Bay Ridge  40.622743 -74.037543  9.738279e+05  166160.5847
# 4  Hammels-Arverne-Edgemere  40.596514 -73.797622  1.040452e+06  156667.5017
#
#    health_score
# 0             3
# 1             3
# 2             3
# 3             3
# 4             3

# %% [markdown]
# Creating a function that will take the input of any boundary column, and return the number of unique tree species per area of the specified boundary:

# %%
def count_unique_species(boundary_column):
    return tree_df.groupby(boundary_column)["spc_common"].nunique().reset_index(name = "unique_species_count")

count_unique_species("cb_num")
# Out:
#     cb_num  unique_species_count
# 0      101                    54
# 1      102                    80
# 2      103                    92
# 3      104                    57
# 4      105                    48
# 5      106                    73
# 6      107                    84
# 7      108                    89
# 8      109                    85
# 9      110                    85
# 10     111                    70
# 11     112                    99
# 12     201                    92
# 13     202                    90
# 14     203                    90
# 15     204                    91
# 16     205                    93
# 17     206                   104
# 18     207                    95
# 19     208                   110
# 20     209                   116
# 21     210                   110
# 22     211                   113
# 23     212                   115
# 24     301                    98
# 25     302                   104
# 26     303                   109
# 27     304                   102
# 28     305                   122
# 29     306                   116
# 30     307                   111
# 31     308                    87
# 32     309                    92
# 33     310                   108
# 34     311                   114
# 35     312                   119
# 36     313                    91
# 37     314                   117
# 38     315                   117
# 39     316                    93
# 40     317                   111
# 41     318                   127
# 42     401                   121
# 43     402                   114
# 44     403                   109
# 45     404                   103
# 46     405                   125
# 47     406                   118
# 48     407                   130
# 49     408                   122
# 50     409                   118
# 51     410                   115
# 52     411                   128
# 53     412                   123
# 54     413                   129
# 55     414                   109
# 56     501                   128
# 57     502                   125
# 58     503                   129

# %% [markdown]
# Creating function to group by any boundary column, and return average health score, average size(diameter), and count of trees in each area:

# %%
def group_by_geography(boundary_column):
    
    """
        agg these:
        avg health_score
        avg tree_dbh
        sum count of trees spc_common
    """
    grouped = tree_df.groupby(boundary_column).agg({"health_score": "mean", "tree_dbh": "mean", "spc_common": "count"})
    return grouped

group_by_geography("cb_num")
# Out:
#         health_score   tree_dbh  spc_common
# cb_num
# 101         2.710057   7.096212        2297
# 102         2.673909   8.898200        4833
# 103         2.708431   8.449352        4709
# 104         2.779814   7.941163        4419
# 105         2.603671   6.374504        2016
# 106         2.705181   8.742188        4864
# 107         2.775084   9.605857        8332
# 108         2.636213   9.334124        8428
# 109         2.715878   9.491483        4755
# 110         2.737571   8.563565        5632
# 111         2.672564   8.219933        4465
# 112         2.618829   7.810082        6745
# 201         2.716785   7.791630        4516
# 202         2.786687   7.340706        4702
# 203         2.805333   8.392369        4613
# 204         2.696535   8.226568        6060
# 205         2.719469   7.198673        4520
# 206         2.682060   8.070494        4894
# 207         2.763204   9.503829        5093
# 208         2.788219  12.152531        5789
# 209         2.832864   9.828384        9597
# 210         2.850083  11.491100       10786
# 211         2.812790  12.610514        9492
# 212         2.828550  11.931002       10522
# 301         2.808352   9.233842       11542
# 302         2.743569  11.373023        8474
# 303         2.797381  10.605346        9165
# 304         2.708083   8.917559        6817
# 305         2.755671   8.883931       15913
# 306         2.748260  11.118709        9915
# 307         2.804700  10.503980        7788
# 308         2.740821  11.239284        5529
# 309         2.816959  12.890253        5130
# 310         2.821820  14.506868       10119
# 311         2.833481  13.793601        9002
# 312         2.792269  12.864323       11977
# 313         2.649933  10.797584        3725
# 314         2.759190  13.931423       10120
# 315         2.705878  14.364610       12981
# 316         2.849464  10.657279        5042
# 317         2.845963  13.811981        8063
# 318         2.775946  15.426852       18442
# 401         2.787414  11.166277       12395
# 402         2.734096  10.825783        8300
# 403         2.768589  12.319341       10315
# 404         2.732266  11.954331        6372
# 405         2.718138  12.669416       18431
# 406         2.781003  13.111293        9749
# 407         2.814317  13.208790       29168
# 408         2.817652  14.466711       19556
# 409         2.772568  14.965067       10878
# 410         2.788755  14.259946       14353
# 411         2.795890  14.672948       26907
# 412         2.847158  13.073899       24980
# 413         2.768789  13.580102       35180
# 414         2.544704   7.862463       11386
# 501         2.819312  11.391834       24689
# 502         2.769339  11.886315       24911
# 503         2.753019   9.994522       51842

# %% [markdown]
# Aggregating data by cb_num(which is the Community Distric number that will be used as the joining key with second data set),
# and creating columns for tree counts and tree diameter metrics:

# %%
tree_agg = tree_df.groupby("cb_num").agg({
    "tree_dbh": ["mean","max"],
    "tree_id": "count",
    "health_score": "mean",
    "spc_common": "nunique"
}).reset_index()
tree_agg.columns = ["cb_num", "dbh_mean", "dbh_max", "tree_count", "avg_health_score", "unique_species"]
tree_agg["dbh_mean"] = tree_agg["dbh_mean"].round(3)
tree_agg["avg_health_score"] = tree_agg["avg_health_score"].round(4)
tree_agg.head()
# Out:
#    cb_num  dbh_mean  dbh_max  tree_count  avg_health_score  unique_species
# 0     101     7.096       88        2297            2.7101              54
# 1     102     8.898       33        4833            2.6739              80
# 2     103     8.449       32        4709            2.7084              92
# 3     104     7.941       38        4419            2.7798              57
# 4     105     6.375       21        2016            2.6037              48

# %%
tree_agg["tree_id"] = range(1, len(tree_agg) + 1)
tree_agg["tree_id"] = tree_agg["tree_id"].astype(str)
new_tree_order = ["tree_id", "cb_num", "tree_count", "avg_health_score", "dbh_mean", "dbh_max", "unique_species"]
tree_agg = tree_agg[new_tree_order]
tree_agg
# Out:
#    tree_id  cb_num  tree_count  avg_health_score  dbh_mean  dbh_max  \
# 0        1     101        2297            2.7101     7.096       88
# 1        2     102        4833            2.6739     8.898       33
# 2        3     103        4709            2.7084     8.449       32
# 3        4     104        4419            2.7798     7.941       38
# 4        5     105        2016            2.6037     6.375       21
# 5        6     106        4864            2.7052     8.742      199
# 6        7     107        8332            2.7751     9.606       54
# 7        8     108        8428            2.6362     9.334       74
# 8        9     109        4755            2.7159     9.491      109
# 9       10     110        5632            2.7376     8.564      228
# 10      11     111        4465            2.6726     8.220       33
# 11      12     112        6745            2.6188     7.810      318
# 12      13     201        4516            2.7168     7.792      149
# 13      14     202        4702            2.7867     7.341       59
# 14      15     203        4613            2.8053     8.392       46
# 15      16     204        6060            2.6965     8.227      291
# 16      17     205        4520            2.7195     7.199      105
# 17      18     206        4894            2.6821     8.070       98
# 18      19     207        5093            2.7632     9.504       49
# 19      20     208        5789            2.7882    12.153       94
# 20      21     209        9597            2.8329     9.828      106
# 21      22     210       10786            2.8501    11.491       62
# 22      23     211        9492            2.8128    12.611      204
# 23      24     212       10522            2.8285    11.931      169
# 24      25     301       11542            2.8084     9.234      151
# 25      26     302        8474            2.7436    11.373      110
# 26      27     303        9165            2.7974    10.605       71
# 27      28     304        6817            2.7081     8.918       52
# 28      29     305       15913            2.7557     8.884      318
# 29      30     306        9915            2.7483    11.119       54
# 30      31     307        7788            2.8047    10.504      195
# 31      32     308        5529            2.7408    11.239      425
# 32      33     309        5130            2.8170    12.890      145
# 33      34     310       10119            2.8218    14.507      170
# 34      35     311        9002            2.8335    13.794      164
# 35      36     312       11977            2.7923    12.864      175
# 36      37     313        3725            2.6499    10.798      118
# 37      38     314       10120            2.7592    13.931      204
# 38      39     315       12981            2.7059    14.365       60
# 39      40     316        5042            2.8495    10.657       45
# 40      41     317        8063            2.8460    13.812      266
# 41      42     318       18442            2.7759    15.427      293
# 42      43     401       12395            2.7874    11.166       78
# 43      44     402        8300            2.7341    10.826       62
# 44      45     403       10315            2.7686    12.319      168
# 45      46     404        6372            2.7323    11.954       50
# 46      47     405       18431            2.7181    12.669      141
# 47      48     406        9749            2.7810    13.111      281
# 48      49     407       29168            2.8143    13.209      181
# 49      50     408       19556            2.8177    14.467       63
# 50      51     409       10878            2.7726    14.965      132
# 51      52     410       14353            2.7888    14.260       64
# 52      53     411       26907            2.7959    14.673      282
# 53      54     412       24980            2.8472    13.074      217
# 54      55     413       35180            2.7688    13.580      389
# 55      56     414       11386            2.5447     7.862      261
# 56      57     501       24689            2.8193    11.392      255
# 57      58     502       24911            2.7693    11.886      250
# 58      59     503       51842            2.7530     9.995      298
#
#     unique_species
# 0               54
# 1               80
# 2               92
# 3               57
# 4               48
# 5               73
# 6               84
# 7               89
# 8               85
# 9               85
# 10              70
# 11              99
# 12              92
# 13              90
# 14              90
# 15              91
# 16              93
# 17             104
# 18              95
# 19             110
# 20             116
# 21             110
# 22             113
# 23             115
# 24              98
# 25             104
# 26             109
# 27             102
# 28             122
# 29             116
# 30             111
# 31              87
# 32              92
# 33             108
# 34             114
# 35             119
# 36              91
# 37             117
# 38             117
# 39              93
# 40             111
# 41             127
# 42             121
# 43             114
# 44             109
# 45             103
# 46             125
# 47             118
# 48             130
# 49             122
# 50             118
# 51             115
# 52             128
# 53             123
# 54             129
# 55             109
# 56             128
# 57             125
# 58             129

# %% [markdown]
# Moving on to second data set.
#
#
# Importing second data set(Air Quality):

# %%
air_df = pd.read_csv("Air_Quality.csv")
air_df.head()
# Out:
#    Unique ID  Indicator ID                                   Name  \
# 0     179772           640  Boiler Emissions- Total SO2 Emissions
# 1     179785           640  Boiler Emissions- Total SO2 Emissions
# 2     178540           365                Fine particles (PM 2.5)
# 3     178561           365                Fine particles (PM 2.5)
# 4     823217           365                Fine particles (PM 2.5)
#
#           Measure Measure Info Geo Type Name  Geo Join ID  \
# 0  Number per km2       number         UHF42        409.0
# 1  Number per km2       number         UHF42        209.0
# 2            Mean       mcg/m3         UHF42        209.0
# 3            Mean       mcg/m3         UHF42        409.0
# 4            Mean       mcg/m3         UHF42        409.0
#
#             Geo Place Name          Time Period  Start_Date  Data Value  \
# 0         Southeast Queens                 2015  01/01/2015         0.3
# 1  Bensonhurst - Bay Ridge                 2015  01/01/2015         1.2
# 2  Bensonhurst - Bay Ridge  Annual Average 2012  12/01/2011         8.6
# 3         Southeast Queens  Annual Average 2012  12/01/2011         8.0
# 4         Southeast Queens          Summer 2022  06/01/2022         6.1
#
#    Message
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %% [markdown]
# Filtering air quality data to include only rows from 2015(which correlates with 2015 tree data in first data set):

# %%
years = air_df["Time Period"].unique()
years
# Out:
# array(['2015', 'Annual Average 2012', 'Summer 2022', 'Summer 2012',
#        'Summer 2013', 'Summer 2021', 'Annual Average 2013',
#        'Annual Average 2017', 'Summer 2009', '2013', 'Summer 2016',
#        'Summer 2011', 'Annual Average 2016', 'Winter 2021-22',
#        'Winter 2010-11', 'Annual Average 2021', 'Winter 2014-15',
#        'Winter 2015-16', 'Annual Average 2018', 'Summer 2014',
#        'Annual Average 2009', 'Annual Average 2015',
#        'Annual Average 2011', 'Summer 2010', 'Winter 2020-21',
#        'Winter 2019-20', 'Winter 2012-13', 'Summer 2015', '2009-2011',
#        '2015-2017', 'Annual Average 2010', 'Summer 2019',
#        'Annual Average 2020', 'Winter 2018-19', '2012-2014',
#        'Annual Average 2019', 'Winter 2017-18', 'Winter 2008-09',
#        'Annual Average 2022', '2005-2007', 'Winter 2013-14', '2010',
#        'Summer 2017', 'Winter 2009-10', 'Winter 2011-12', 'Summer 2020',
#        'Summer 2018', 'Annual Average 2014', 'Winter 2016-17',
#        '2017-2019', '2005', '2019', '2-Year Summer Average 2009-2010',
#        '2014', '2011'], dtype=object)

# %%
air_df_2015 = air_df[air_df["Time Period"].isin(["Annual Average 2015", "Winter 2015-16", "Summer 2015"])]
air_df_2015.head()
# Out:
#      Unique ID  Indicator ID                     Name Measure Measure Info  \
# 43      410828           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 144     334003           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 176     412469           375   Nitrogen dioxide (NO2)    Mean          ppb
# 186     336803           375   Nitrogen dioxide (NO2)    Mean          ppb
# 208     412481           375   Nitrogen dioxide (NO2)    Mean          ppb
#
#     Geo Type Name  Geo Join ID           Geo Place Name          Time Period  \
# 43          UHF42        404.0    Bayside - Little Neck       Winter 2015-16
# 144         UHF42        211.0  Williamsburg - Bushwick  Annual Average 2015
# 176         UHF42        208.0     Canarsie - Flatlands       Winter 2015-16
# 186            CD        304.0           Bushwick (CD4)          Summer 2015
# 208         UHF42        301.0       Washington Heights       Winter 2015-16
#
#      Start_Date  Data Value  Message
# 43   12/01/2015         7.4      NaN
# 144  01/01/2015         9.6      NaN
# 176  12/01/2015        20.9      NaN
# 186  06/01/2015        15.5      NaN
# 208  12/01/2015        23.4      NaN

# %% [markdown]
# Cleaning air quality data and dealing with null values:

# %%
#dropping unneeded columns:
air_2015_df = air_df_2015.drop(["Measure", "Start_Date", "Message", "Unique ID", "Geo Place Name"], axis=1)
air_2015_df.head()
# Out:
#      Indicator ID                     Name Measure Info Geo Type Name  \
# 43            365  Fine particles (PM 2.5)       mcg/m3         UHF42
# 144           365  Fine particles (PM 2.5)       mcg/m3         UHF42
# 176           375   Nitrogen dioxide (NO2)          ppb         UHF42
# 186           375   Nitrogen dioxide (NO2)          ppb            CD
# 208           375   Nitrogen dioxide (NO2)          ppb         UHF42
#
#      Geo Join ID          Time Period  Data Value
# 43         404.0       Winter 2015-16         7.4
# 144        211.0  Annual Average 2015         9.6
# 176        208.0       Winter 2015-16        20.9
# 186        304.0          Summer 2015        15.5
# 208        301.0       Winter 2015-16        23.4

# %%
#renaming columns:
air_2015_df = air_2015_df.rename(columns={"Indicator ID": "Indicator_ID", "Measure Info": "Measure_Info", "Geo Type Name": "Geo_Type_Name",
                                          "Geo Join ID": "Geo_Join_ID", "Time Period": "Time_Period", "Data Value": "Data_Value"})
air_2015_df
# Out:
#        Indicator_ID                     Name Measure_Info Geo_Type_Name  \
# 43              365  Fine particles (PM 2.5)       mcg/m3         UHF42
# 144             365  Fine particles (PM 2.5)       mcg/m3         UHF42
# 176             375   Nitrogen dioxide (NO2)          ppb         UHF42
# 186             375   Nitrogen dioxide (NO2)          ppb            CD
# 208             375   Nitrogen dioxide (NO2)          ppb         UHF42
# ...             ...                      ...          ...           ...
# 17886           375   Nitrogen dioxide (NO2)          ppb         UHF34
# 17959           375   Nitrogen dioxide (NO2)          ppb         UHF34
# 17961           375   Nitrogen dioxide (NO2)          ppb         UHF34
# 17964           375   Nitrogen dioxide (NO2)          ppb         UHF34
# 17968           375   Nitrogen dioxide (NO2)          ppb         UHF34
#
#        Geo_Join_ID          Time_Period  Data_Value
# 43           404.0       Winter 2015-16         7.4
# 144          211.0  Annual Average 2015         9.6
# 176          208.0       Winter 2015-16        20.9
# 186          304.0          Summer 2015        15.5
# 208          301.0       Winter 2015-16        23.4
# ...            ...                  ...         ...
# 17886        201.0  Annual Average 2015        21.7
# 17959        405.0       Winter 2015-16        23.4
# 17961        402.0       Winter 2015-16        25.0
# 17964        402.0          Summer 2015        16.3
# 17968        402.0  Annual Average 2015        21.1
#
# [987 rows x 7 columns]

# %%
#checking for null values:
air_2015_df.isnull().sum()
# Out:
# Indicator_ID     0
# Name             0
# Measure_Info     0
# Geo_Type_Name    0
# Geo_Join_ID      0
# Time_Period      0
# Data_Value       0
# dtype: int64

# %% [markdown]
# Finding which Geo IDs will correlate with my tree data(which has CD-community district boundaries):

# %%
air_2015_df["Geo_Type_Name"].unique()
# Out:
# array(['UHF42', 'CD', 'Borough', 'UHF34', 'Citywide'], dtype=object)

# %%
air_2015_df[air_2015_df["Geo_Type_Name"] == "CD"].describe()
# Out:
#        Indicator_ID  Geo_Join_ID  Data_Value
# count    413.000000   413.000000  413.000000
# mean     372.285714   280.305085   16.978935
# std        7.273487   117.901015    8.352525
# min      365.000000   101.000000    5.900000
# 25%      365.000000   203.000000    9.300000
# 50%      375.000000   306.000000   15.300000
# 75%      375.000000   403.000000   23.600000
# max      386.000000   503.000000   37.500000

# %%
#filtering to only include rows with a CD boundary:
cd_df = air_2015_df[air_2015_df["Geo_Type_Name"] == "CD"]
cd_df = cd_df.drop(["Geo_Type_Name", "Indicator_ID"], axis=1)
cd_df = cd_df.reset_index()
cd_df = cd_df.drop(["index"], axis=1)
cd_df
# Out:
#                         Name Measure_Info  Geo_Join_ID          Time_Period  \
# 0     Nitrogen dioxide (NO2)          ppb        304.0          Summer 2015
# 1     Nitrogen dioxide (NO2)          ppb        410.0       Winter 2015-16
# 2     Nitrogen dioxide (NO2)          ppb        301.0          Summer 2015
# 3     Nitrogen dioxide (NO2)          ppb        409.0          Summer 2015
# 4     Nitrogen dioxide (NO2)          ppb        304.0  Annual Average 2015
# ..                       ...          ...          ...                  ...
# 408  Fine particles (PM 2.5)       mcg/m3        403.0       Winter 2015-16
# 409  Fine particles (PM 2.5)       mcg/m3        404.0       Winter 2015-16
# 410   Nitrogen dioxide (NO2)          ppb        303.0  Annual Average 2015
# 411   Nitrogen dioxide (NO2)          ppb        503.0  Annual Average 2015
# 412   Nitrogen dioxide (NO2)          ppb        404.0  Annual Average 2015
#
#      Data_Value
# 0          15.5
# 1          22.5
# 2          17.0
# 3          14.4
# 4          20.3
# ..          ...
# 408         7.7
# 409         8.1
# 410        21.3
# 411        11.8
# 412        21.9
#
# [413 rows x 5 columns]

# %%
cd_df["id"] = range(1, len(cd_df) + 1)
cd_df
# Out:
#                         Name Measure_Info  Geo_Join_ID          Time_Period  \
# 0     Nitrogen dioxide (NO2)          ppb        304.0          Summer 2015
# 1     Nitrogen dioxide (NO2)          ppb        410.0       Winter 2015-16
# 2     Nitrogen dioxide (NO2)          ppb        301.0          Summer 2015
# 3     Nitrogen dioxide (NO2)          ppb        409.0          Summer 2015
# 4     Nitrogen dioxide (NO2)          ppb        304.0  Annual Average 2015
# ..                       ...          ...          ...                  ...
# 408  Fine particles (PM 2.5)       mcg/m3        403.0       Winter 2015-16
# 409  Fine particles (PM 2.5)       mcg/m3        404.0       Winter 2015-16
# 410   Nitrogen dioxide (NO2)          ppb        303.0  Annual Average 2015
# 411   Nitrogen dioxide (NO2)          ppb        503.0  Annual Average 2015
# 412   Nitrogen dioxide (NO2)          ppb        404.0  Annual Average 2015
#
#      Data_Value   id
# 0          15.5    1
# 1          22.5    2
# 2          17.0    3
# 3          14.4    4
# 4          20.3    5
# ..          ...  ...
# 408         7.7  409
# 409         8.1  410
# 410        21.3  411
# 411        11.8  412
# 412        21.9  413
#
# [413 rows x 6 columns]

# %%
new_air_order = ["id", "Geo_Join_ID", "Time_Period", "Name", "Data_Value", "Measure_Info"]
cd_df = cd_df[new_air_order]
cd_df
# Out:
#       id  Geo_Join_ID          Time_Period                     Name  \
# 0      1        304.0          Summer 2015   Nitrogen dioxide (NO2)
# 1      2        410.0       Winter 2015-16   Nitrogen dioxide (NO2)
# 2      3        301.0          Summer 2015   Nitrogen dioxide (NO2)
# 3      4        409.0          Summer 2015   Nitrogen dioxide (NO2)
# 4      5        304.0  Annual Average 2015   Nitrogen dioxide (NO2)
# ..   ...          ...                  ...                      ...
# 408  409        403.0       Winter 2015-16  Fine particles (PM 2.5)
# 409  410        404.0       Winter 2015-16  Fine particles (PM 2.5)
# 410  411        303.0  Annual Average 2015   Nitrogen dioxide (NO2)
# 411  412        503.0  Annual Average 2015   Nitrogen dioxide (NO2)
# 412  413        404.0  Annual Average 2015   Nitrogen dioxide (NO2)
#
#      Data_Value Measure_Info
# 0          15.5          ppb
# 1          22.5          ppb
# 2          17.0          ppb
# 3          14.4          ppb
# 4          20.3          ppb
# ..          ...          ...
# 408         7.7       mcg/m3
# 409         8.1       mcg/m3
# 410        21.3          ppb
# 411        11.8          ppb
# 412        21.9          ppb
#
# [413 rows x 6 columns]

# %%
cd_df["id"] = cd_df["id"].astype(str)
cd_df.dtypes
# Out:
# id               object
# Geo_Join_ID     float64
# Time_Period      object
# Name             object
# Data_Value      float64
# Measure_Info     object
# dtype: object

# %% [markdown]
# Both data sets are clean and ready to work with.
#
# Renaming data sets to "air" and "tree" to simplify code moving forward:
#
# Saving datasets to csv files to work with SQLite database:

# %%
air = cd_df
air.head()
# Out:
#   id  Geo_Join_ID          Time_Period                    Name  Data_Value  \
# 0  1        304.0          Summer 2015  Nitrogen dioxide (NO2)        15.5
# 1  2        410.0       Winter 2015-16  Nitrogen dioxide (NO2)        22.5
# 2  3        301.0          Summer 2015  Nitrogen dioxide (NO2)        17.0
# 3  4        409.0          Summer 2015  Nitrogen dioxide (NO2)        14.4
# 4  5        304.0  Annual Average 2015  Nitrogen dioxide (NO2)        20.3
#
#   Measure_Info
# 0          ppb
# 1          ppb
# 2          ppb
# 3          ppb
# 4          ppb

# %%
air.to_csv("Air_quality_by_CD.csv", index=False)

# %%
tree = tree_agg
tree.head()
# Out:
#   tree_id  cb_num  tree_count  avg_health_score  dbh_mean  dbh_max  \
# 0       1     101        2297            2.7101     7.096       88
# 1       2     102        4833            2.6739     8.898       33
# 2       3     103        4709            2.7084     8.449       32
# 3       4     104        4419            2.7798     7.941       38
# 4       5     105        2016            2.6037     6.375       21
#
#    unique_species
# 0              54
# 1              80
# 2              92
# 3              57
# 4              48

# %%
tree.to_csv("tree_summary_by_cb.csv", index=False)

# %% [markdown]
# ____________________________________________________________________________________________________________________________________________

# %% [markdown]
# I don't yet know if it will be better to work with the data as two separate sets, or all together.
#
# So, combining cleaned and filtered air and tree data sets, and saving to csv file to have both options:

# %%
combined_df = pd.merge(air, tree, left_on="Geo_Join_ID", right_on="cb_num", how="left")
combined_df.head()
# Out:
#   id  Geo_Join_ID          Time_Period                    Name  Data_Value  \
# 0  1        304.0          Summer 2015  Nitrogen dioxide (NO2)        15.5
# 1  2        410.0       Winter 2015-16  Nitrogen dioxide (NO2)        22.5
# 2  3        301.0          Summer 2015  Nitrogen dioxide (NO2)        17.0
# 3  4        409.0          Summer 2015  Nitrogen dioxide (NO2)        14.4
# 4  5        304.0  Annual Average 2015  Nitrogen dioxide (NO2)        20.3
#
#   Measure_Info tree_id  cb_num  tree_count  avg_health_score  dbh_mean  \
# 0          ppb      28     304        6817            2.7081     8.918
# 1          ppb      52     410       14353            2.7888    14.260
# 2          ppb      25     301       11542            2.8084     9.234
# 3          ppb      51     409       10878            2.7726    14.965
# 4          ppb      28     304        6817            2.7081     8.918
#
#    dbh_max  unique_species
# 0       52             102
# 1       64             115
# 2      151              98
# 3      132             118
# 4       52             102

# %%
#checking that all rows filled in:
set(tree["cb_num"]) - set(air["Geo_Join_ID"])
# Out:
# set()

# %%
#double checking all rows filled in:
combined_df[combined_df["tree_count"].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, Geo_Join_ID, Time_Period, Name, Data_Value, Measure_Info, tree_id, cb_num, tree_count, avg_health_score, dbh_mean, dbh_max, unique_species]
# Index: []

# %%
air_and_tree = combined_df
air_and_tree.to_csv("combined_air_and_tree.csv", index=False)

# %% [markdown]
# _____________________________________________________________________________________________________________________________________________________

# %% [markdown]
# Trying out some plots:

# %%
air_and_tree.head()
# Out:
#   id  Geo_Join_ID          Time_Period                    Name  Data_Value  \
# 0  1        304.0          Summer 2015  Nitrogen dioxide (NO2)        15.5
# 1  2        410.0       Winter 2015-16  Nitrogen dioxide (NO2)        22.5
# 2  3        301.0          Summer 2015  Nitrogen dioxide (NO2)        17.0
# 3  4        409.0          Summer 2015  Nitrogen dioxide (NO2)        14.4
# 4  5        304.0  Annual Average 2015  Nitrogen dioxide (NO2)        20.3
#
#   Measure_Info tree_id  cb_num  tree_count  avg_health_score  dbh_mean  \
# 0          ppb      28     304        6817            2.7081     8.918
# 1          ppb      52     410       14353            2.7888    14.260
# 2          ppb      25     301       11542            2.8084     9.234
# 3          ppb      51     409       10878            2.7726    14.965
# 4          ppb      28     304        6817            2.7081     8.918
#
#    dbh_max  unique_species
# 0       52             102
# 1       64             115
# 2      151              98
# 3      132             118
# 4       52             102

# %%
plt.scatter(air_and_tree["cb_num"], air_and_tree["avg_health_score"])
plt.title("Average Tree Health by Community District")
plt.xlabel("Community District")
plt.ylabel("Tree Health Score")
plt.show()

# %%
plt.scatter(air_and_tree["cb_num"], air_and_tree["Data_Value"])
plt.title("Average Pollution by Community District")
plt.xlabel("Community District")
plt.ylabel("Pollution")
plt.show()

# %% [markdown]
# I can see there is an outlier of a low tree health and an outlier of high pollution.  I am going to explore if these come from the same community district.

# %%
air_and_tree.sort_values(by="Data_Value", ascending=False)
# Out:
#       id  Geo_Join_ID     Time_Period                     Name  Data_Value  \
# 293  294        414.0     Summer 2015               Ozone (O3)        37.5
# 339  340        313.0     Summer 2015               Ozone (O3)        35.8
# 340  341        315.0     Summer 2015               Ozone (O3)        34.8
# 299  300        318.0     Summer 2015               Ozone (O3)        34.7
# 377  378        503.0     Summer 2015               Ozone (O3)        34.1
# ..   ...          ...             ...                      ...         ...
# 391  392        313.0  Winter 2015-16  Fine particles (PM 2.5)         6.9
# 6      7        413.0  Winter 2015-16  Fine particles (PM 2.5)         6.9
# 250  251        414.0     Summer 2015   Nitrogen dioxide (NO2)         6.9
# 405  406        503.0     Summer 2015   Nitrogen dioxide (NO2)         6.6
# 351  352        414.0  Winter 2015-16  Fine particles (PM 2.5)         5.9
#
#     Measure_Info tree_id  cb_num  tree_count  avg_health_score  dbh_mean  \
# 293          ppb      56     414       11386            2.5447     7.862
# 339          ppb      37     313        3725            2.6499    10.798
# 340          ppb      39     315       12981            2.7059    14.365
# 299          ppb      42     318       18442            2.7759    15.427
# 377          ppb      59     503       51842            2.7530     9.995
# ..           ...     ...     ...         ...               ...       ...
# 391       mcg/m3      37     313        3725            2.6499    10.798
# 6         mcg/m3      55     413       35180            2.7688    13.580
# 250          ppb      56     414       11386            2.5447     7.862
# 405          ppb      59     503       51842            2.7530     9.995
# 351       mcg/m3      56     414       11386            2.5447     7.862
#
#      dbh_max  unique_species
# 293      261             109
# 339      118              91
# 340       60             117
# 299      293             127
# 377      298             129
# ..       ...             ...
# 391      118              91
# 6        389             129
# 250      261             109
# 405      298             129
# 351      261             109
#
# [413 rows x 13 columns]

# %%
air_and_tree.sort_values(by="avg_health_score", ascending=True)
# Out:
#       id  Geo_Join_ID          Time_Period                     Name  \
# 351  352        414.0       Winter 2015-16  Fine particles (PM 2.5)
# 350  351        414.0       Winter 2015-16   Nitrogen dioxide (NO2)
# 250  251        414.0          Summer 2015   Nitrogen dioxide (NO2)
# 23    24        414.0  Annual Average 2015   Nitrogen dioxide (NO2)
# 213  214        414.0          Summer 2015  Fine particles (PM 2.5)
# ..   ...          ...                  ...                      ...
# 256  257        210.0          Summer 2015   Nitrogen dioxide (NO2)
# 242  243        210.0  Annual Average 2015   Nitrogen dioxide (NO2)
# 218  219        210.0  Annual Average 2015  Fine particles (PM 2.5)
# 20    21        210.0       Winter 2015-16   Nitrogen dioxide (NO2)
# 355  356        210.0       Winter 2015-16  Fine particles (PM 2.5)
#
#      Data_Value Measure_Info tree_id  cb_num  tree_count  avg_health_score  \
# 351         5.9       mcg/m3      56     414       11386            2.5447
# 350        17.9          ppb      56     414       11386            2.5447
# 250         6.9          ppb      56     414       11386            2.5447
# 23         13.4          ppb      56     414       11386            2.5447
# 213         8.3       mcg/m3      56     414       11386            2.5447
# ..          ...          ...     ...     ...         ...               ...
# 256        14.6          ppb      22     210       10786            2.8501
# 242        18.8          ppb      22     210       10786            2.8501
# 218         9.0       mcg/m3      22     210       10786            2.8501
# 20         21.4          ppb      22     210       10786            2.8501
# 355         8.1       mcg/m3      22     210       10786            2.8501
#
#      dbh_mean  dbh_max  unique_species
# 351     7.862      261             109
# 350     7.862      261             109
# 250     7.862      261             109
# 23      7.862      261             109
# 213     7.862      261             109
# ..        ...      ...             ...
# 256    11.491       62             110
# 242    11.491       62             110
# 218    11.491       62             110
# 20     11.491       62             110
# 355    11.491       62             110
#
# [413 rows x 13 columns]

# %%
cb_414 = air_and_tree[air_and_tree["cb_num"] == 414]
cb_414
# Out:
#       id  Geo_Join_ID          Time_Period                     Name  \
# 23    24        414.0  Annual Average 2015   Nitrogen dioxide (NO2)
# 212  213        414.0  Annual Average 2015  Fine particles (PM 2.5)
# 213  214        414.0          Summer 2015  Fine particles (PM 2.5)
# 250  251        414.0          Summer 2015   Nitrogen dioxide (NO2)
# 293  294        414.0          Summer 2015               Ozone (O3)
# 350  351        414.0       Winter 2015-16   Nitrogen dioxide (NO2)
# 351  352        414.0       Winter 2015-16  Fine particles (PM 2.5)
#
#      Data_Value Measure_Info tree_id  cb_num  tree_count  avg_health_score  \
# 23         13.4          ppb      56     414       11386            2.5447
# 212         7.2       mcg/m3      56     414       11386            2.5447
# 213         8.3       mcg/m3      56     414       11386            2.5447
# 250         6.9          ppb      56     414       11386            2.5447
# 293        37.5          ppb      56     414       11386            2.5447
# 350        17.9          ppb      56     414       11386            2.5447
# 351         5.9       mcg/m3      56     414       11386            2.5447
#
#      dbh_mean  dbh_max  unique_species
# 23      7.862      261             109
# 212     7.862      261             109
# 213     7.862      261             109
# 250     7.862      261             109
# 293     7.862      261             109
# 350     7.862      261             109
# 351     7.862      261             109

# %%
borough_df = tree_df.groupby("boroname").agg({
    "spc_common": "nunique",
    "tree_dbh": ["mean", "sum"],
    "health_score": "mean",
    "tree_id": "count"}).reset_index()
borough_df.columns = ["boroname", "unique_species", "avg_dbh", "total_dbh", "avg_health_score", "total_trees"]

borough_df["avg_dbh"] = borough_df["avg_dbh"].round(3)
borough_df["avg_health_score"] = borough_df["avg_health_score"].round(4)

borough_df.head()
# Out:
#         boroname  unique_species  avg_dbh  total_dbh  avg_health_score  \
# 0          Bronx             132   10.083     812562            2.7881
# 1       Brooklyn             132   12.165    2064944            2.7762
# 2      Manhattan             128    8.635     531005            2.6972
# 3         Queens             132   13.099    3117148            2.7757
# 4  Staten Island             131   10.799    1095489            2.7732
#
#    total_trees
# 0        80584
# 1       169744
# 2        61495
# 3       237970
# 4       101442

# %%
borough_df.to_csv("borough_tree.csv", index=False)
