# %% [markdown]
# Importing needed libraries:

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import geopandas as gpd
import sqlite3

# %% [markdown]
# Importing and cleaning first data set(Tree census):

# %%
tree_df = pd.read_csv("new_york_tree_census_2015.csv")
tree_df.head()
# Out:
#    tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status health  \
# 0   606945    305778  2016-06-28        10           0   OnCurb  Alive   Good
# 1   160321    341273  2015-08-19         9           0   OnCurb  Alive   Good
# 2   541347    325281  2015-12-30         7           0   OnCurb  Alive   Good
# 3   613930    203822  2016-07-05        10           0   OnCurb  Alive   Good
# 4    18353    338911  2015-06-13         4           0   OnCurb  Alive   Good
#
#                             spc_latin              spc_common  ... st_assem  \
# 0              Fraxinus pennsylvanica               green ash  ...       25
# 1  Gleditsia triacanthos var. inermis             honeylocust  ...       34
# 2                    Pyrus calleryana            Callery pear  ...       32
# 3                    Pyrus calleryana            Callery pear  ...       46
# 4                   Prunus virginiana  'Schubert' chokecherry  ...       31
#
#   st_senate   nta                  nta_name  boro_ct     state   latitude  \
# 0        14  QN37         Kew Gardens Hills  4125700  New York  40.724339
# 1        13  QN28           Jackson Heights  4030902  New York  40.756626
# 2        10  QN76              Baisley Park  4028800  New York  40.679777
# 3        22  BK31                 Bay Ridge  3005000  New York  40.622743
# 4        10  QN12  Hammels-Arverne-Edgemere  4095400  New York  40.596514
#
#    longitude          x_sp         y_sp
# 0 -73.805180  1.038250e+06  203232.9417
# 1 -73.894167  1.013571e+06  214953.6472
# 2 -73.788463  1.042923e+06  187008.2671
# 3 -74.037543  9.738279e+05  166160.5847
# 4 -73.797622  1.040452e+06  156667.5017
#
# [5 rows x 41 columns]

# %%
#keeping only living trees:
remove_values = ["Dead", "Stump"]
alive_df = tree_df[~tree_df["status"].isin(remove_values)]
alive_df.describe()
# Out:
#              tree_id       block_id       tree_dbh  stump_diam        zipcode  \
# count  652173.000000  652173.000000  652173.000000    652173.0  652173.000000
# mean   365689.637480  313611.213077      11.709485         0.0   10914.407958
# std    208194.926983  114775.077889       8.634239         0.0     656.868397
# min         3.000000  100002.000000       0.000000         0.0      83.000000
# 25%    186886.000000  221491.000000       5.000000         0.0   10314.000000
# 50%    367204.000000  319886.000000      10.000000         0.0   11214.000000
# 75%    546632.000000  404665.000000      16.000000         0.0   11365.000000
# max    722694.000000  999999.000000     425.000000         0.0   11697.000000
#
#               cb_num       borocode       cncldist       st_assem  \
# count  652173.000000  652173.000000  652173.000000  652173.000000
# mean      343.738388       3.360979      29.992976      50.818103
# std       115.808325       1.167572      14.343667      18.928937
# min       101.000000       1.000000       1.000000      23.000000
# 25%       303.000000       3.000000      19.000000      33.000000
# 50%       402.000000       4.000000      30.000000      52.000000
# 75%       412.000000       4.000000      43.000000      64.000000
# max       503.000000       5.000000      51.000000      87.000000
#
#            st_senate       boro_ct       latitude      longitude  \
# count  652173.000000  6.521730e+05  652173.000000  652173.000000
# mean       20.620725  3.407340e+06      40.700991     -73.924587
# std         7.378427  1.176612e+06       0.090268       0.123844
# min        10.000000  1.000201e+06      40.498466     -74.254965
# 25%        14.000000  3.012000e+06      40.631725     -73.980973
# 50%        21.000000  4.008100e+06      40.700287     -73.913449
# 75%        25.000000  4.103300e+06      40.761999     -73.835219
# max        36.000000  5.032300e+06      40.912918     -73.700488
#
#                x_sp           y_sp
# count  6.521730e+05  652173.000000
# mean   1.005133e+06  194699.696220
# std    3.435720e+04   32886.140551
# min    9.133493e+05  120973.792200
# 25%    9.895259e+05  169441.751400
# 50%    1.008235e+06  194444.837500
# 75%    1.029902e+06  216940.389000
# max    1.067248e+06  271894.092100

# %%
#dropping unneeded columns:
filtered_df = alive_df.drop(['created_at', 'stump_diam', 'status', 'user_type', 'sidewalk', 'guards', 'steward', 'st_assem', 
                             'st_senate', 'root_stone', 'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
                             'brch_light', 'brch_shoe', 'brch_other'], axis=1)
filtered_df.head()
# Out:
#    tree_id  block_id  tree_dbh curb_loc health  \
# 0   606945    305778        10   OnCurb   Good
# 1   160321    341273         9   OnCurb   Good
# 2   541347    325281         7   OnCurb   Good
# 3   613930    203822        10   OnCurb   Good
# 4    18353    338911         4   OnCurb   Good
#
#                             spc_latin              spc_common      problems  \
# 0              Fraxinus pennsylvanica               green ash        Stones
# 1  Gleditsia triacanthos var. inermis             honeylocust  BranchLights
# 2                    Pyrus calleryana            Callery pear  BranchLights
# 3                    Pyrus calleryana            Callery pear           NaN
# 4                   Prunus virginiana  'Schubert' chokecherry  BranchLights
#
#                address  zipcode  ...  boroname  cncldist   nta  \
# 0    76-046 164 STREET    11366  ...    Queens        24  QN37
# 1     72-020 32 AVENUE    11370  ...    Queens        25  QN28
# 2   153-026 119 AVENUE    11434  ...    Queens        28  QN76
# 3         89 89 STREET    11209  ...  Brooklyn        43  BK31
# 4  559 BEACH 68 STREET    11692  ...    Queens        31  QN12
#
#                    nta_name  boro_ct     state   latitude  longitude  \
# 0         Kew Gardens Hills  4125700  New York  40.724339 -73.805180
# 1           Jackson Heights  4030902  New York  40.756626 -73.894167
# 2              Baisley Park  4028800  New York  40.679777 -73.788463
# 3                 Bay Ridge  3005000  New York  40.622743 -74.037543
# 4  Hammels-Arverne-Edgemere  4095400  New York  40.596514 -73.797622
#
#            x_sp         y_sp
# 0  1.038250e+06  203232.9417
# 1  1.013571e+06  214953.6472
# 2  1.042923e+06  187008.2671
# 3  9.738279e+05  166160.5847
# 4  1.040452e+06  156667.5017
#
# [5 rows x 23 columns]

# %% [markdown]
# Addressing null or unclear values:

# %%
filtered_df.isnull().sum()
# Out:
# tree_id            0
# block_id           0
# tree_dbh           0
# curb_loc           0
# health             1
# spc_latin          5
# spc_common         5
# problems      426329
# address            0
# zipcode            0
# zip_city           0
# cb_num             0
# borocode           0
# boroname           0
# cncldist           0
# nta                0
# nta_name           0
# boro_ct            0
# state              0
# latitude           0
# longitude          0
# x_sp               0
# y_sp               0
# dtype: int64

# %%
filtered_df.dropna(subset=["health", "spc_latin", "spc_common"], inplace=True)

# %%
filtered_df["problems"] = filtered_df["problems"].fillna("no problems")
filtered_df.head()
# Out:
#    tree_id  block_id  tree_dbh curb_loc health  \
# 0   606945    305778        10   OnCurb   Good
# 1   160321    341273         9   OnCurb   Good
# 2   541347    325281         7   OnCurb   Good
# 3   613930    203822        10   OnCurb   Good
# 4    18353    338911         4   OnCurb   Good
#
#                             spc_latin              spc_common      problems  \
# 0              Fraxinus pennsylvanica               green ash        Stones
# 1  Gleditsia triacanthos var. inermis             honeylocust  BranchLights
# 2                    Pyrus calleryana            Callery pear  BranchLights
# 3                    Pyrus calleryana            Callery pear   no problems
# 4                   Prunus virginiana  'Schubert' chokecherry  BranchLights
#
#                address  zipcode  ...  boroname  cncldist   nta  \
# 0    76-046 164 STREET    11366  ...    Queens        24  QN37
# 1     72-020 32 AVENUE    11370  ...    Queens        25  QN28
# 2   153-026 119 AVENUE    11434  ...    Queens        28  QN76
# 3         89 89 STREET    11209  ...  Brooklyn        43  BK31
# 4  559 BEACH 68 STREET    11692  ...    Queens        31  QN12
#
#                    nta_name  boro_ct     state   latitude  longitude  \
# 0         Kew Gardens Hills  4125700  New York  40.724339 -73.805180
# 1           Jackson Heights  4030902  New York  40.756626 -73.894167
# 2              Baisley Park  4028800  New York  40.679777 -73.788463
# 3                 Bay Ridge  3005000  New York  40.622743 -74.037543
# 4  Hammels-Arverne-Edgemere  4095400  New York  40.596514 -73.797622
#
#            x_sp         y_sp
# 0  1.038250e+06  203232.9417
# 1  1.013571e+06  214953.6472
# 2  1.042923e+06  187008.2671
# 3  9.738279e+05  166160.5847
# 4  1.040452e+06  156667.5017
#
# [5 rows x 23 columns]

# %%
filtered_df["zipcode"].unique()
# Out:
# array([11366, 11370, 11434, 11209, 11692, 10031, 11207, 11219, 11421,
#        10474, 11419, 10308, 10001, 10312, 11234, 10305, 11201, 11233,
#        11411, 11220, 10009, 11372, 11432, 10314, 10461, 10309, 11367,
#        11205, 10025, 11374, 11105, 11217, 10458, 11001, 10459, 11364,
#        11379, 11691, 11004, 11358, 11238, 11213, 10470, 11356, 11103,
#        11361, 10007, 11385, 11355, 11230, 10469, 10468, 10032, 11426,
#        10304, 10463, 11206, 10462, 11216, 11208, 10465, 11375, 11429,
#        11365, 11435, 11218, 10034, 11414, 11412, 11377, 11223, 11427,
#        11204, 11357, 10022, 11215, 11428, 10036, 10456, 10024, 11221,
#        10467, 10026, 11420, 11423, 10038, 11231, 11369, 11413, 10453,
#        11210, 11436, 10307, 10475, 11229, 11363, 11040, 10003, 10457,
#        11212, 11373, 11360, 11418, 11226, 10301, 10473, 10472, 11225,
#        10302, 11422, 11354, 11236, 11106, 10013, 11214, 10452, 11378,
#        10466, 10012,    83, 10310, 11694, 10002, 11224, 10464, 10035,
#        11415, 10306, 11222, 10303, 11368, 10014, 10451, 11433, 11239,
#        10021, 10018, 11237, 11235, 11249, 11211, 10017, 10029, 10128,
#        11102, 10011, 11104, 11693, 10019, 10006, 11228, 10040, 10455,
#        11362, 10028, 10471, 10033, 10454, 11101, 10023, 10065, 11203,
#        10075, 10460, 10016, 11371, 10037, 11416, 10027, 10004, 11232,
#        10039, 10010, 10030, 11417, 10020, 11109, 10281, 11251, 10069,
#        10280, 10005, 11430, 10282, 11005, 11697, 10111, 11096, 10115,
#        11451, 10048])

# %%
filtered_df = filtered_df[filtered_df["zipcode"] != 83]
filtered_df["zipcode"].unique()
# Out:
# array([11366, 11370, 11434, 11209, 11692, 10031, 11207, 11219, 11421,
#        10474, 11419, 10308, 10001, 10312, 11234, 10305, 11201, 11233,
#        11411, 11220, 10009, 11372, 11432, 10314, 10461, 10309, 11367,
#        11205, 10025, 11374, 11105, 11217, 10458, 11001, 10459, 11364,
#        11379, 11691, 11004, 11358, 11238, 11213, 10470, 11356, 11103,
#        11361, 10007, 11385, 11355, 11230, 10469, 10468, 10032, 11426,
#        10304, 10463, 11206, 10462, 11216, 11208, 10465, 11375, 11429,
#        11365, 11435, 11218, 10034, 11414, 11412, 11377, 11223, 11427,
#        11204, 11357, 10022, 11215, 11428, 10036, 10456, 10024, 11221,
#        10467, 10026, 11420, 11423, 10038, 11231, 11369, 11413, 10453,
#        11210, 11436, 10307, 10475, 11229, 11363, 11040, 10003, 10457,
#        11212, 11373, 11360, 11418, 11226, 10301, 10473, 10472, 11225,
#        10302, 11422, 11354, 11236, 11106, 10013, 11214, 10452, 11378,
#        10466, 10012, 10310, 11694, 10002, 11224, 10464, 10035, 11415,
#        10306, 11222, 10303, 11368, 10014, 10451, 11433, 11239, 10021,
#        10018, 11237, 11235, 11249, 11211, 10017, 10029, 10128, 11102,
#        10011, 11104, 11693, 10019, 10006, 11228, 10040, 10455, 11362,
#        10028, 10471, 10033, 10454, 11101, 10023, 10065, 11203, 10075,
#        10460, 10016, 11371, 10037, 11416, 10027, 10004, 11232, 10039,
#        10010, 10030, 11417, 10020, 11109, 10281, 11251, 10069, 10280,
#        10005, 11430, 10282, 11005, 11697, 10111, 11096, 10115, 11451,
#        10048])

# %%
filtered_df.isnull().sum()
# Out:
# tree_id       0
# block_id      0
# tree_dbh      0
# curb_loc      0
# health        0
# spc_latin     0
# spc_common    0
# problems      0
# address       0
# zipcode       0
# zip_city      0
# cb_num        0
# borocode      0
# boroname      0
# cncldist      0
# nta           0
# nta_name      0
# boro_ct       0
# state         0
# latitude      0
# longitude     0
# x_sp          0
# y_sp          0
# dtype: int64

# %%
#dropping more unneeded columns:
tree_df = filtered_df.drop(["block_id", "state", "cncldist", "nta", "boro_ct", "spc_latin", "address", "zip_city"], axis=1)
tree_df = tree_df.reset_index()
tree_df.head()
# Out:
#    index  tree_id  tree_dbh curb_loc health              spc_common  \
# 0      0   606945        10   OnCurb   Good               green ash
# 1      1   160321         9   OnCurb   Good             honeylocust
# 2      2   541347         7   OnCurb   Good            Callery pear
# 3      3   613930        10   OnCurb   Good            Callery pear
# 4      4    18353         4   OnCurb   Good  'Schubert' chokecherry
#
#        problems  zipcode  cb_num  borocode  boroname  \
# 0        Stones    11366     408         4    Queens
# 1  BranchLights    11370     403         4    Queens
# 2  BranchLights    11434     412         4    Queens
# 3   no problems    11209     310         3  Brooklyn
# 4  BranchLights    11692     414         4    Queens
#
#                    nta_name   latitude  longitude          x_sp         y_sp
# 0         Kew Gardens Hills  40.724339 -73.805180  1.038250e+06  203232.9417
# 1           Jackson Heights  40.756626 -73.894167  1.013571e+06  214953.6472
# 2              Baisley Park  40.679777 -73.788463  1.042923e+06  187008.2671
# 3                 Bay Ridge  40.622743 -74.037543  9.738279e+05  166160.5847
# 4  Hammels-Arverne-Edgemere  40.596514 -73.797622  1.040452e+06  156667.5017

# %% [markdown]
# Aggregating data by cb_num(which is the Community Distric number that will be used as the joining key with second data set),
# and creating columns for tree counts and tree diameter metrics:

# %%
tree_agg = tree_df.groupby("cb_num").agg({
    "tree_dbh": ["mean", "median","max"],
    "tree_id": "count"
}).reset_index()
tree_agg.columns = ["cb_num", "dbh_mean", "dbh_median", "dbh_max", "tree_count"]
tree_agg["dbh_mean"] = tree_agg["dbh_mean"].round(3)
tree_agg.head()
# Out:
#    cb_num  dbh_mean  dbh_median  dbh_max  tree_count
# 0     101     7.096         6.0       88        2297
# 1     102     8.898         8.0       33        4833
# 2     103     8.449         7.0       32        4709
# 3     104     7.941         8.0       38        4419
# 4     105     6.375         6.0       21        2016

# %% [markdown]
# Saving the dataframe as a csv file to use later with the SQLite database:

# %%
tree_agg.to_csv("tree_summary_by_cb.csv", index=False)

# %% [markdown]
# Moving on to second data set.
#
#
# Importing second data set(Air Quality):

# %%
air_df = pd.read_csv("Air_Quality.csv")
air_df.head()
# Out:
#    Unique ID  Indicator ID                                   Name  \
# 0     179772           640  Boiler Emissions- Total SO2 Emissions
# 1     179785           640  Boiler Emissions- Total SO2 Emissions
# 2     178540           365                Fine particles (PM 2.5)
# 3     178561           365                Fine particles (PM 2.5)
# 4     823217           365                Fine particles (PM 2.5)
#
#           Measure Measure Info Geo Type Name  Geo Join ID  \
# 0  Number per km2       number         UHF42        409.0
# 1  Number per km2       number         UHF42        209.0
# 2            Mean       mcg/m3         UHF42        209.0
# 3            Mean       mcg/m3         UHF42        409.0
# 4            Mean       mcg/m3         UHF42        409.0
#
#             Geo Place Name          Time Period  Start_Date  Data Value  \
# 0         Southeast Queens                 2015  01/01/2015         0.3
# 1  Bensonhurst - Bay Ridge                 2015  01/01/2015         1.2
# 2  Bensonhurst - Bay Ridge  Annual Average 2012  12/01/2011         8.6
# 3         Southeast Queens  Annual Average 2012  12/01/2011         8.0
# 4         Southeast Queens          Summer 2022  06/01/2022         6.1
#
#    Message
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %% [markdown]
# Filtering air quality data to include only rows from 2015(which correlates with 2015 tree data in first data set):

# %%
years = air_df["Time Period"].unique()
years
# Out:
# array(['2015', 'Annual Average 2012', 'Summer 2022', 'Summer 2012',
#        'Summer 2013', 'Summer 2021', 'Annual Average 2013',
#        'Annual Average 2017', 'Summer 2009', '2013', 'Summer 2016',
#        'Summer 2011', 'Annual Average 2016', 'Winter 2021-22',
#        'Winter 2010-11', 'Annual Average 2021', 'Winter 2014-15',
#        'Winter 2015-16', 'Annual Average 2018', 'Summer 2014',
#        'Annual Average 2009', 'Annual Average 2015',
#        'Annual Average 2011', 'Summer 2010', 'Winter 2020-21',
#        'Winter 2019-20', 'Winter 2012-13', 'Summer 2015', '2009-2011',
#        '2015-2017', 'Annual Average 2010', 'Summer 2019',
#        'Annual Average 2020', 'Winter 2018-19', '2012-2014',
#        'Annual Average 2019', 'Winter 2017-18', 'Winter 2008-09',
#        'Annual Average 2022', '2005-2007', 'Winter 2013-14', '2010',
#        'Summer 2017', 'Winter 2009-10', 'Winter 2011-12', 'Summer 2020',
#        'Summer 2018', 'Annual Average 2014', 'Winter 2016-17',
#        '2017-2019', '2005', '2019', '2-Year Summer Average 2009-2010',
#        '2014', '2011'], dtype=object)

# %%
air_df_2015 = air_df[air_df["Time Period"].isin(["Annual Average 2015", "Winter 2015-16", "Summer 2015"])]
air_df_2015.head()
# Out:
#      Unique ID  Indicator ID                     Name Measure Measure Info  \
# 43      410828           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 144     334003           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 176     412469           375   Nitrogen dioxide (NO2)    Mean          ppb
# 186     336803           375   Nitrogen dioxide (NO2)    Mean          ppb
# 208     412481           375   Nitrogen dioxide (NO2)    Mean          ppb
#
#     Geo Type Name  Geo Join ID           Geo Place Name          Time Period  \
# 43          UHF42        404.0    Bayside - Little Neck       Winter 2015-16
# 144         UHF42        211.0  Williamsburg - Bushwick  Annual Average 2015
# 176         UHF42        208.0     Canarsie - Flatlands       Winter 2015-16
# 186            CD        304.0           Bushwick (CD4)          Summer 2015
# 208         UHF42        301.0       Washington Heights       Winter 2015-16
#
#      Start_Date  Data Value  Message
# 43   12/01/2015         7.4      NaN
# 144  01/01/2015         9.6      NaN
# 176  12/01/2015        20.9      NaN
# 186  06/01/2015        15.5      NaN
# 208  12/01/2015        23.4      NaN

# %% [markdown]
# Cleaning air quality data and dealing with null values:

# %%
#dropping unneeded columns:
air_2015_df = air_df_2015.drop(["Measure", "Start_Date", "Message", "Unique ID", "Geo Place Name"], axis=1)
air_2015_df.head()
# Out:
#      Indicator ID                     Name Measure Info Geo Type Name  \
# 43            365  Fine particles (PM 2.5)       mcg/m3         UHF42
# 144           365  Fine particles (PM 2.5)       mcg/m3         UHF42
# 176           375   Nitrogen dioxide (NO2)          ppb         UHF42
# 186           375   Nitrogen dioxide (NO2)          ppb            CD
# 208           375   Nitrogen dioxide (NO2)          ppb         UHF42
#
#      Geo Join ID          Time Period  Data Value
# 43         404.0       Winter 2015-16         7.4
# 144        211.0  Annual Average 2015         9.6
# 176        208.0       Winter 2015-16        20.9
# 186        304.0          Summer 2015        15.5
# 208        301.0       Winter 2015-16        23.4

# %%
#renaming columns:
air_2015_df = air_2015_df.rename(columns={"Indicator ID": "Indicator_ID", "Measure Info": "Measure_Info", "Geo Type Name": "Geo_Type_Name",
                                          "Geo Join ID": "Geo_Join_ID", "Time Period": "Time_Period", "Data Value": "Data_Value"})
air_2015_df
# Out:
#        Indicator_ID                     Name Measure_Info Geo_Type_Name  \
# 43              365  Fine particles (PM 2.5)       mcg/m3         UHF42
# 144             365  Fine particles (PM 2.5)       mcg/m3         UHF42
# 176             375   Nitrogen dioxide (NO2)          ppb         UHF42
# 186             375   Nitrogen dioxide (NO2)          ppb            CD
# 208             375   Nitrogen dioxide (NO2)          ppb         UHF42
# ...             ...                      ...          ...           ...
# 17886           375   Nitrogen dioxide (NO2)          ppb         UHF34
# 17959           375   Nitrogen dioxide (NO2)          ppb         UHF34
# 17961           375   Nitrogen dioxide (NO2)          ppb         UHF34
# 17964           375   Nitrogen dioxide (NO2)          ppb         UHF34
# 17968           375   Nitrogen dioxide (NO2)          ppb         UHF34
#
#        Geo_Join_ID          Time_Period  Data_Value
# 43           404.0       Winter 2015-16         7.4
# 144          211.0  Annual Average 2015         9.6
# 176          208.0       Winter 2015-16        20.9
# 186          304.0          Summer 2015        15.5
# 208          301.0       Winter 2015-16        23.4
# ...            ...                  ...         ...
# 17886        201.0  Annual Average 2015        21.7
# 17959        405.0       Winter 2015-16        23.4
# 17961        402.0       Winter 2015-16        25.0
# 17964        402.0          Summer 2015        16.3
# 17968        402.0  Annual Average 2015        21.1
#
# [987 rows x 7 columns]

# %%
#checking for null values:
air_2015_df.isnull().sum()
# Out:
# Indicator_ID     0
# Name             0
# Measure_Info     0
# Geo_Type_Name    0
# Geo_Join_ID      0
# Time_Period      0
# Data_Value       0
# dtype: int64

# %% [markdown]
# Finding which Geo IDs will correlate with my tree data(which has CD-community district boundaries):

# %%
air_2015_df["Geo_Type_Name"].unique()
# Out:
# array(['UHF42', 'CD', 'Borough', 'UHF34', 'Citywide'], dtype=object)

# %%
air_2015_df[air_2015_df["Geo_Type_Name"] == "CD"].describe()
# Out:
#        Indicator_ID  Geo_Join_ID  Data_Value
# count    413.000000   413.000000  413.000000
# mean     372.285714   280.305085   16.978935
# std        7.273487   117.901015    8.352525
# min      365.000000   101.000000    5.900000
# 25%      365.000000   203.000000    9.300000
# 50%      375.000000   306.000000   15.300000
# 75%      375.000000   403.000000   23.600000
# max      386.000000   503.000000   37.500000

# %%
#filtering to only include rows with a CD boundary:
cd_df = air_2015_df[air_2015_df["Geo_Type_Name"] == "CD"]
cd_df = cd_df.drop(["Geo_Type_Name"], axis=1)
cd_df = cd_df.reset_index()
cd_df
# Out:
#      index  Indicator_ID                     Name Measure_Info  Geo_Join_ID  \
# 0      186           375   Nitrogen dioxide (NO2)          ppb        304.0
# 1      415           375   Nitrogen dioxide (NO2)          ppb        410.0
# 2      442           375   Nitrogen dioxide (NO2)          ppb        301.0
# 3      479           375   Nitrogen dioxide (NO2)          ppb        409.0
# 4      516           375   Nitrogen dioxide (NO2)          ppb        304.0
# ..     ...           ...                      ...          ...          ...
# 408  17135           365  Fine particles (PM 2.5)       mcg/m3        403.0
# 409  17138           365  Fine particles (PM 2.5)       mcg/m3        404.0
# 410  17349           375   Nitrogen dioxide (NO2)          ppb        303.0
# 411  17690           375   Nitrogen dioxide (NO2)          ppb        503.0
# 412  17692           375   Nitrogen dioxide (NO2)          ppb        404.0
#
#              Time_Period  Data_Value
# 0            Summer 2015        15.5
# 1         Winter 2015-16        22.5
# 2            Summer 2015        17.0
# 3            Summer 2015        14.4
# 4    Annual Average 2015        20.3
# ..                   ...         ...
# 408       Winter 2015-16         7.7
# 409       Winter 2015-16         8.1
# 410  Annual Average 2015        21.3
# 411  Annual Average 2015        11.8
# 412  Annual Average 2015        21.9
#
# [413 rows x 7 columns]

# %% [markdown]
# Both data sets are clean and ready to work with.
# Renaming data sets to "air" and "tree" to simplify code moving forward:

# %%
air = cd_df
air.head()
# Out:
#    index  Indicator_ID                    Name Measure_Info  Geo_Join_ID  \
# 0    186           375  Nitrogen dioxide (NO2)          ppb        304.0
# 1    415           375  Nitrogen dioxide (NO2)          ppb        410.0
# 2    442           375  Nitrogen dioxide (NO2)          ppb        301.0
# 3    479           375  Nitrogen dioxide (NO2)          ppb        409.0
# 4    516           375  Nitrogen dioxide (NO2)          ppb        304.0
#
#            Time_Period  Data_Value
# 0          Summer 2015        15.5
# 1       Winter 2015-16        22.5
# 2          Summer 2015        17.0
# 3          Summer 2015        14.4
# 4  Annual Average 2015        20.3

# %%
tree = tree_agg
tree.head()
# Out:
#    cb_num  dbh_mean  dbh_median  dbh_max  tree_count
# 0     101     7.096         6.0       88        2297
# 1     102     8.898         8.0       33        4833
# 2     103     8.449         7.0       32        4709
# 3     104     7.941         8.0       38        4419
# 4     105     6.375         6.0       21        2016

# %% [markdown]
# Combining air quality and tree census data sets:

# %%
combined_df = pd.merge(air, tree, left_on="Geo_Join_ID", right_on="cb_num", how="left")
combined_df.head()
# Out:
#    index  Indicator_ID                    Name Measure_Info  Geo_Join_ID  \
# 0    186           375  Nitrogen dioxide (NO2)          ppb        304.0
# 1    415           375  Nitrogen dioxide (NO2)          ppb        410.0
# 2    442           375  Nitrogen dioxide (NO2)          ppb        301.0
# 3    479           375  Nitrogen dioxide (NO2)          ppb        409.0
# 4    516           375  Nitrogen dioxide (NO2)          ppb        304.0
#
#            Time_Period  Data_Value  cb_num  dbh_mean  dbh_median  dbh_max  \
# 0          Summer 2015        15.5     304     8.918         7.0       52
# 1       Winter 2015-16        22.5     410    14.260        13.0       64
# 2          Summer 2015        17.0     301     9.234         8.0      151
# 3          Summer 2015        14.4     409    14.965        13.0      132
# 4  Annual Average 2015        20.3     304     8.918         7.0       52
#
#    tree_count
# 0        6817
# 1       14353
# 2       11542
# 3       10878
# 4        6817

# %% [markdown]
# Checking to see if data combined successfully with no null values.

# %%
set(tree["cb_num"]) - set(air["Geo_Join_ID"])
# Out:
# set()

# %%
combined_df[combined_df["tree_count"].isnull()]
# Out:
# Empty DataFrame
# Columns: [index, Indicator_ID, Name, Measure_Info, Geo_Join_ID, Time_Period, Data_Value, cb_num, dbh_mean, dbh_median, dbh_max, tree_count]
# Index: []
