# %% [markdown]
# exploring energy dataset

# %%
import pandas as pd

# %%
energy_df = pd.read_csv("energy_disclosure_2021_rows.csv")
energy_df
# Out:
#     10_Digit_BBL  Street_Number     Street_Name  DOF_Gross_Square_Footage  \
# 0     1007610020            325  WEST 37 STREET                     48843
# 1     1007610022            313  WEST 37 STREET                     82354
# 2     1007610028            307  WEST 37 STREET                    102824
# 3     1007610033            545        8 AVENUE                    166874
# 4     1007610037            555        8 AVENUE                    162260
# ..           ...            ...             ...                       ...
# 95    1000370013            129    FRONT STREET                     34613
# 96    1000370023            180     MAIDEN LANE                   1079361
# 97    1000380001            100     WALL STREET                    463664
# 98    1000380017             88     PINE STREET                    664990
# 99    1000390012            110     MAIDEN LANE                   1104184
#
#    Energy_Efficiency_Grade  Energy_Star_1-100_Score
# ...
